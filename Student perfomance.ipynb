# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data=pd.read_csv('C:\\Users\\rajeshwari\\MACHINE LEARNING\\ML datasets\\Student Performance Analysis\\student-por (1).csv')

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
data.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
data.nunique()
# Out:
# school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      24
# G1            17
# G2            16
# G3            17
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 35 columns):
# school        649 non-null object
# sex           649 non-null object
# age           649 non-null int64
# address       649 non-null object
# famsize       649 non-null object
# Pstatus       649 non-null object
# Medu          649 non-null int64
# Fedu          649 non-null int64
# Mjob          649 non-null object
# Fjob          649 non-null object
# reason        649 non-null object
# guardian      649 non-null object
# traveltime    649 non-null int64
# studytime     649 non-null int64
# failures      649 non-null int64
# schoolsup     649 non-null object
# famsup        649 non-null object
# paid          649 non-null object
# activities    649 non-null object
# nursery       649 non-null object
# higher        649 non-null object
# internet      649 non-null object
# romantic      649 non-null object
# famrel        649 non-null int64
# ...

# %%
data['G']=(data['G1']+data['G2']+data['G3'])/3

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3          G
# 0        3     4     1     1       3        4   0  11  11   7.333333
# 1        3     3     1     1       3        2   9  11  11  10.333333
# 2        3     2     2     3       3        6  12  13  12  12.333333
# 3        2     2     1     1       5        0  14  14  14  14.000000
# 4        3     2     1     2       5        0  11  13  13  12.333333
#
# [5 rows x 34 columns]

# %%
df=data

# %%
result=[]
for x in df['G']:
    if x>=(0.5*20):
        result.append('P')
    
    else:
        result.append('F')
df['result']=result

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   goout Dalc  Walc  health  absences  G1  G2  G3          G result
# 0     4    1     1       3         4   0  11  11   7.333333      F
# 1     3    1     1       3         2   9  11  11  10.333333      P
# 2     2    2     3       3         6  12  13  12  12.333333      P
# 3     2    1     1       5         0  14  14  14  14.000000      P
# 4     2    1     2       5         0  11  13  13  12.333333      P
#
# [5 rows x 35 columns]

# %%
data['result']=result

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   goout Dalc  Walc  health  absences  G1  G2  G3          G result
# 0     4    1     1       3         4   0  11  11   7.333333      F
# 1     3    1     1       3         2   9  11  11  10.333333      P
# 2     2    2     3       3         6  12  13  12  12.333333      P
# 3     2    1     1       5         0  14  14  14  14.000000      P
# 4     2    1     2       5         0  11  13  13  12.333333      P
#
# [5 rows x 35 columns]

# %%
#Exploring the percentage of each gender on both the schools.
explode = (0.1,0)  
fig1, ax1 = plt.subplots(figsize=(12,7))
ax1.pie(data['sex'].value_counts(), explode=explode,labels=['Male','Female'], autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal')  
plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
#                         Male percentage is more as compare to female from both the school

# %%
#Defining a plot function to group a certain column with respect to another column.
def plot(group,column,plot):
    ax=plt.figure(figsize=(12,6))
    data.groupby(group)[column].sum().sort_values().plot(plot)

# Relation between the sex and G.
plot('sex','G','bar')

# %% [markdown]
#                         Female grades are more compare to male.

# %%
#Comparing the Age with respect to the gender of the students.
fig1, ax1 = plt.subplots(figsize=(32,7))
sns.countplot(data['sex'],hue=data['age'])

# %% [markdown]
#                                  Female age count is more compare to male age count.

# %%
#Relation b/w school and absences
plot('school','absences','bar')

# %%
#Exploring the percentage of Pstatus of students.
explode = (0.1,0)  
fig1, ax1 = plt.subplots(figsize=(12,7))
ax1.pie(data['Pstatus'].value_counts(), explode=explode,labels=['Apart','living together'], autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal')  
plt.tight_layout()
plt.legend()
plt.show()

# %%
# The status of students home address.
explode = (0.1, 0)
fig1, ax1 = plt.subplots(figsize=(12,7))
ax1.pie(data['address'].value_counts(),explode=explode, labels=['Urban','Rural'], autopct='%1.1f%%',
        shadow=True, startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.legend()
plt.show()

# %%
# The status of mother's education of students
labels=['none','pre elementary education','primary education','secondary education','higher education']
explode = (0,0,0,0,0.3)
fig1, ax1 = plt.subplots(figsize=(12,7))
ax1.pie(data['Medu'].value_counts(),explode=explode,labels=labels, autopct='%1.1f%%',shadow=True,)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.legend()
plt.show()

# %%
#Relation b/w school and and grade in horizontal Histogram.
plot('school','G','barh')

# %%
# Rating Vs Category plot.
g = sns.catplot(x="age",y="G",data=data, kind="box", height = 10 ,
palette = "Set1")
g.despine(left=True)
g.set_xticklabels(rotation=90)
g.set( xticks=range(0,34))
g = g.set_ylabels("Grade")
plt.title('Boxplot of Age VS Grade',size = 20)
# Out:
# Text(0.5, 1, 'Boxplot of Age VS Grade')

# %%
df=data.drop(['G1','G2','G3','G'],axis=1)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   internet romantic  famrel  freetime  goout Dalc Walc health absences result
# 0       no       no       4         3      4    1    1      3        4      F
# 1      yes       no       5         3      3    1    1      3        2      P
# 2      yes       no       4         3      2    2    3      3        6      P
# 3      yes      yes       3         2      2    1    1      5        0      P
# 4       no       no       4         3      2    1    2      5        0      P
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(data.corr(),annot=True,cmap='coolwarm')

# %%
df1=df.drop('result',axis=1)

# %%
df1=pd.get_dummies(df1)

# %%
df1.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         0       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  ...  activities_no  activities_yes  nursery_no  nursery_yes  \
# 0     1  ...              1               0           0            1
# 1     1  ...              1               0           1            0
# 2     2  ...              1               0           0            1
# 3     1  ...              0               1           0            1
# 4     1  ...              1               0           0            1
#
#    higher_no  higher_yes  internet_no  internet_yes  romantic_no  romantic_yes
# ...

# %%
x=df1
y=df['result']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
models=[]
models.append(('LR',LogisticRegression()))
models.append(('LDA',LinearDiscriminantAnalysis()))
models.append(('KNN',KNeighborsClassifier()))
models.append(('CART',DecisionTreeClassifier()))
models.append(('NB',GaussianNB()))
models.append(('RFC',RandomForestClassifier()))
#models.append(('SVM',SVC()))
models.append(('ETC',ExtraTreesClassifier()))
models.append(('GRAD',GradientBoostingClassifier()))
models.append(('ADA',AdaBoostClassifier()))
models.append(('BAGG',BaggingClassifier()))
results=[]
names=[]
for name,model in models:
    kfold=KFold(n_splits=10,random_state=7)
    cv_results=cross_val_score(model,x_train,y_train,cv=kfold,scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    msg="%s: %f(%f)" %(name,cv_results.mean(),cv_results.std())
    print(msg)
# Out:
# LR: 0.816931(0.059811)
# LDA: 0.834201(0.055562)
# KNN: 0.782240(0.051054)
# CART: 0.766817(0.059403)
# NB: 0.770551(0.077774)
# RFC: 0.795777(0.057112)
# ETC: 0.797587(0.059533)
# GRAD: 0.809351(0.068835)
# ADA: 0.801546(0.063204)
# BAGG: 0.784087(0.052032)

# %%
# Modeling:

#Import svm model
from sklearn.linear_model import LogisticRegression

#Create a svm Classifier
clf = LogisticRegression() # Linear Kernel

#Train the model using the training sets
clf.fit(x_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array(['P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'F', 'P', 'F', 'P',
#        'P', 'F', 'P', 'P', 'F', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'F',
#        'P', 'F', 'P', 'P', 'P', 'P', 'F', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'F', 'F', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'F',
#        'P', 'P', 'P', 'P', 'F', 'P', 'F', 'F', 'F', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'F', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'F', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'F', 'P', 'P', 'P', 'P', 'P', 'P', 'P'],
#       dtype=object)

# %%
# Model evaluation:

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8076923076923077

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[11, 19],
#        [ 6, 94]], dtype=int64)

# %%
CR=classification_report(y_test,y_pred)
print(CR)
# Out:
#               precision    recall  f1-score   support
#
#            F       0.65      0.37      0.47        30
#            P       0.83      0.94      0.88       100
#
#     accuracy                           0.81       130
#    macro avg       0.74      0.65      0.68       130
# weighted avg       0.79      0.81      0.79       130

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cm), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')
